# %%
# !gdown --id text

# %%
import pandas as pd

datos=pd.read_excel("Data.xls")
df = pd.DataFrame(datos)

# %%
df
# Out:
#         1      2      3      4      5   ...     48     49     50     51     52
# 0   -0.145 -0.345 -0.200 -0.200 -0.375  ... -0.380 -0.200 -0.245 -0.095 -0.080
# 1   -0.145 -0.345 -0.200 -0.200 -0.375  ... -0.380 -0.200 -0.245 -0.095 -0.080
# 2   -0.145 -0.345 -0.200 -0.200 -0.375  ... -0.380 -0.200 -0.245 -0.095 -0.080
# 3   -0.145 -0.345 -0.200 -0.200 -0.375  ... -0.380 -0.200 -0.245 -0.095 -0.080
# 4   -0.145 -0.345 -0.200 -0.200 -0.375  ... -0.380 -0.200 -0.245 -0.095 -0.080
# ..     ...    ...    ...    ...    ...  ...    ...    ...    ...    ...    ...
# 995 -0.395 -0.335  0.125  0.125 -0.315  ... -0.430 -0.015 -0.015 -0.650 -0.035
# 996 -0.390 -0.355  0.110  0.110 -0.305  ... -0.440 -0.040  0.030 -0.645 -0.010
# 997 -0.385 -0.365  0.125  0.125 -0.300  ... -0.445 -0.055  0.115 -0.630 -0.010
# 998 -0.375 -0.365  0.135  0.135 -0.315  ... -0.435 -0.075  0.195 -0.630 -0.010
# 999 -0.385 -0.380  0.140  0.140 -0.335  ... -0.420 -0.100  0.395 -0.650 -0.025
#
# ...

# %%
df[1]
# Out:
# 0     -0.145
# 1     -0.145
# 2     -0.145
# 3     -0.145
# 4     -0.145
#        ...
# 995   -0.395
# 996   -0.390
# 997   -0.385
# 998   -0.375
# 999   -0.385
# Name: 1, Length: 1000, dtype: float64

# %%
df.shape
# Out:
# (1000, 52)

# %%
import matplotlib.pyplot as plt

x=df[1]

plt.plot(x)
plt.show()

# %%
i=1
while i<=52:
  x=df[i]
  plt.plot(x)
  t=str(i)
  name="/content/drive/MyDrive/Ordenador/Imges-Isquemia/Esquemia-"+t+".png"
  plt.savefig(name, bbox_inches='tight')
  i=i+1
  plt.clf()

# %%
# !pip install wfdb
# Out:
# ...
#      |████████████████████████████████| 137 kB 4.1 MB/s
# ...

# %%
import wfdb #WaveForm-Database package. A library of tools for reading, writing, and processing WFDB signals and annotations.
import pandas as pd
import numpy as np
import glob

# %%
# !gdown --id text
# Out:
# Downloading...
# From: link
# To: /content/s20021.dat
# 56.9MB [00:00, 156MB/s]

# %%
# !ls
# Out:
# drive	    s20011.ari	s20011.dat	s20011.sta  s20011.stf	    sample_data
# Images	    s20011.atr	s20011.hea	s20011.stb  s20011.tsr.zip
# s20011.16a  s20011.cnt	s20011.klt.zip	s20011.stc  s20021.dat

# %%
# !wget -r -N -c -np https://physionet.org/files/ltstdb/1.0.0/
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
#
# 2021-07-20 12:51:14 (196 MB/s) - ‘physionet.org/files/ltstdb/1.0.0/trends/s20631_00-24.png’ saved [37063/37063]
#
# --2021-07-20 12:51:14--  https://physionet.org/files/ltstdb/1.0.0/trends/s20631_05-11.png
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 37896 (37K) [image/png]
# Saving to: ‘physionet.org/files/ltstdb/1.0.0/trends/s20631_05-11.png’
#
# physionet.org/files 100%[===================>]  37.01K  --.-KB/s    in 0s
#
# 2021-07-20 12:51:14 (223 MB/s) - ‘physionet.org/files/ltstdb/1.0.0/trends/s20631_05-11.png’ saved [37896/37896]
#
# --2021-07-20 12:51:14--  https://physionet.org/files/ltstdb/1.0.0/trends/s20631_10-16.png
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 29384 (29K) [image/png]
# Saving to: ‘physionet.org/files/ltstdb/1.0.0/trends/s20631_10-16.png’
#
# ...

# %%
data_files=glob.glob('/content/physionet.org/files/ltstdb/1.0.0/*.dat')
print(data_files)
# Out:
# ['/content/physionet.org/files/ltstdb/1.0.0/s20631.dat', '/content/physionet.org/files/ltstdb/1.0.0/s30681.dat', '/content/physionet.org/files/ltstdb/1.0.0/s20451.dat', '/content/physionet.org/files/ltstdb/1.0.0/s20531.dat', '/content/physionet.org/files/ltstdb/1.0.0/s20041.dat', '/content/physionet.org/files/ltstdb/1.0.0/s30742.dat', '/content/physionet.org/files/ltstdb/1.0.0/s20111.dat', '/content/physionet.org/files/ltstdb/1.0.0/s20161.dat', '/content/physionet.org/files/ltstdb/1.0.0/s20301.dat', '/content/physionet.org/files/ltstdb/1.0.0/s20231.dat', '/content/physionet.org/files/ltstdb/1.0.0/s20141.dat', '/content/physionet.org/files/ltstdb/1.0.0/s20471.dat', '/content/physionet.org/files/ltstdb/1.0.0/s20021.dat', '/content/physionet.org/files/ltstdb/1.0.0/s30721.dat', '/content/physionet.org/files/ltstdb/1.0.0/s20601.dat', '/content/physionet.org/files/ltstdb/1.0.0/s20251.dat', '/content/physionet.org/files/ltstdb/1.0.0/s30731.dat', '/content/physionet.org/files/ltstdb/1.0.0/s2
# ...

# %%
#/content/physionet.org/files/ltstdb/1.0.0
dat_files=glob.glob('/content/physionet.org/files/ltstdb/1.0.0/*.dat') #Get list of all .dat files in the current folder
df=pd.DataFrame(data=dat_files)
df.to_csv("files_list.csv",index=False,header=None) #Write the list to a CSV file
files=pd.read_csv("files_list.csv",header=None)
recordname=str(files.iloc[[0]])
print(recordname)
record = wfdb.rdsamp(recordname)
# Out:
#                                                    0
# 0  /content/physionet.org/files/ltstdb/1.0.0/s206...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-60-33911426c988> in <module>()
#       6 recordname=str(files.iloc[[0]])
#       7 print(recordname)
# ----> 8 record = wfdb.rdsamp(recordname)
#
# /usr/local/lib/python3.7/dist-packages/wfdb/io/record.py in rdsamp(record_name, sampfrom, sampto, channels, pn_dir, channel_names, warn_empty, return_res)
#    3720                       sampto=sampto, channels=channels, physical=True,
#    3721                       pn_dir=pn_dir, m2s=True, return_res=return_res,
# -> 3722                       channel_names=channel_names, warn_empty=warn_empty)
#    3723
#    3724     signals = record.p_signal
#
# ...

# %%
for i in range(1,len(files)+1):
	recordname=str(files.iloc[[i]])
	print(recordname[:-4])
	recordname_new=recordname[-7:-4] #Extracting just the filename part (will differ from database to database)
	record = wfdb.rdsamp(recordname_new) # rdsamp() returns the signal as a numpy array  
	record=np.asarray(record[0])
	path=recordname_new+".csv"
	np.savetxt(path,record,delimiter=",") #Writing the CSV for each record
	print("Files done: %s/%s"% (i,len(files)))

print("\nAll files done!")

# %%
import wfdb
record = wfdb.rdsamp('/content/physionet.org/files/ltstdb/1.0.0/s20041', sampto=600)

# %%
type(record)
# Out:
# tuple

# %%
tn=record[0]

# %%
record

# %%
tn.shape
# Out:
# (600, 2)

# %%
plt.plot(tn)
plt.show()

# %%
df = pd.DataFrame(data=tn, columns=["1", "2"])
df
# Out:
#          1      2
# 0   -0.750 -0.475
# 1   -0.770 -0.475
# 2   -0.790 -0.475
# 3   -0.770 -0.475
# 4   -0.750 -0.475
# ..     ...    ...
# 595 -0.535 -0.660
# 596 -0.540 -0.660
# 597 -0.530 -0.660
# 598 -0.520 -0.660
# 599 -0.520 -0.650
#
# [600 rows x 2 columns]

# %%
plt.plot(df["1"])
plt.show()

# %%
plt.plot(df["2"])
plt.show()

# %%
# !wget -r -N -c -np https://physionet.org/files/mitdb/1.0.0/
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# Length: 5468 (5.3K) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/223.atr’
#
# physionet.org/files 100%[===================>]   5.34K  --.-KB/s    in 0s
#
# 2021-07-20 14:27:18 (456 MB/s) - ‘physionet.org/files/mitdb/1.0.0/223.atr’ saved [5468/5468]
#
# --2021-07-20 14:27:18--  https://physionet.org/files/mitdb/1.0.0/223.dat
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1950000 (1.9M) [application/octet-stream]
# Saving to: ‘physionet.org/files/mitdb/1.0.0/223.dat’
#
# physionet.org/files 100%[===================>]   1.86M  --.-KB/s    in 0.09s
#
# 2021-07-20 14:27:18 (21.0 MB/s) - ‘physionet.org/files/mitdb/1.0.0/223.dat’ saved [1950000/1950000]
#
# --2021-07-20 14:27:18--  https://physionet.org/files/mitdb/1.0.0/223.hea
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# ...

# %%
# !wget -r -N -c -np https://physionet.org/files/nsrdb/1.0.0/
# Out:
# --2021-07-24 11:27:54--  https://physionet.org/files/nsrdb/1.0.0/
# Resolving physionet.org (physionet.org)... 18.18.42.54
# Connecting to physionet.org (physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘physionet.org/files/nsrdb/1.0.0/index.html’
#
# physionet.org/files     [ <=>                ]   8.58K  --.-KB/s    in 0s
#
# Last-modified header missing -- time-stamps turned off.
# 2021-07-24 11:27:55 (163 MB/s) - ‘physionet.org/files/nsrdb/1.0.0/index.html’ saved [8781]
#
# Loading robots.txt; please ignore errors.
# --2021-07-24 11:27:55--  https://physionet.org/robots.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
#
#     The file is already fully retrieved; nothing to do.
#
# --2021-07-24 11:27:55--  https://physionet.org/files/nsrdb/1.0.0/16265.atr
# Reusing existing connection to physionet.org:443.
# ...

# %%
# !wget -r -N -c -np https://physionet.org/files/nsrdb/1.0.0/
# Out:
# --2021-08-01 21:06:55--  https://physionet.org/files/nsrdb/1.0.0/
# Resolving physionet.org (physionet.org)... 18.18.42.54
# Connecting to physionet.org (physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘physionet.org/files/nsrdb/1.0.0/index.html’
#
# physionet.org/files     [ <=>                ]   8.58K  --.-KB/s    in 0s
#
# Last-modified header missing -- time-stamps turned off.
# 2021-08-01 21:06:56 (132 MB/s) - ‘physionet.org/files/nsrdb/1.0.0/index.html’ saved [8781]
#
# Loading robots.txt; please ignore errors.
# --2021-08-01 21:06:56--  https://physionet.org/robots.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 22 [text/plain]
# Saving to: ‘physionet.org/robots.txt’
#
# physionet.org/robot 100%[===================>]      22  --.-KB/s    in 0s
#
# ...

# %%
import wfdb
record = wfdb.rdsamp('/content/physionet.org/files/nsrdb/1.0.0/16265', sampto=200)
tn=record[0]

# %%
tn.shape
# Out:
# (200, 2)

# %%
import matplotlib.pyplot as plt
plt.plot(tn)
plt.show()

# %% [markdown]
# Isquemia - Arritmia
